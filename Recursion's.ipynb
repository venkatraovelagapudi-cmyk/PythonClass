# %%
def numbers(n):
    if n==1:
        print(n)
        return 1
    print(n)
    numbers(n-1) # fucntion calllllllllllllllllllllllllllllllllllllllllllllllllll
numbers(5)
# Out:
# 5
# 4
# 3
# 2
# 1

# %%
def numbers(n):
    if n==1:
        print(n)
        return 1
    numbers(n-1) # fucntion calllllllllllllllllllllllllllllllllllllllllllllllllll
    print(n)
    
numbers(5)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
def numbers(n):
    if n==1:
        return [1]
    lst=numbers(n-1) # fucntion calllllllllllllllllllllllllllllllllllllllllllllllllll
    lst.append(n)
    return lst
    
print(numbers(5))
# Out:
# [1, 2, 3, 4, 5]

# %%
def is_even(n):
    if n==0:
        return True
    return is_odd(n-1)
def is_odd(n):
    if n==0:
        return False
    return is_even(n-1)
print(is_odd(2))
# Out:
# False
