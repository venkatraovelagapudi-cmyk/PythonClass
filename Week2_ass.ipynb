# %%
# WEEK 2 Exam ASSissnment

# %%
lst=[1,2,3,4]
lst.append(6)
print(lst)
lst.extend([7,8])
print(lst)
lst.insert(0,9)
print(lst)
print(lst.pop())
print(max(lst))
# Out:
# [1, 2, 3, 4, 6]
# [1, 2, 3, 4, 6, 7, 8]
# [9, 1, 2, 3, 4, 6, 7, 8]
# 8
# 9

# %%
marks=[72,85,60,50,45]
marks.append(65)
marks.append(75)
marks.append(90)
marks.sort(reverse=True)
marks.pop()
if max(marks)>=90:
    print("Topper exists!")
else:
    print("No topper this time")
print(marks,len(marks))
# Out:
# Topper exists!
# [90, 85, 75, 72, 65, 60, 50] 7

# %%
username=input().strip()
if username[0].isalpha():
    if len(username)>=6:
        print(username.upper())
# Out:
#            venkatrao
# VENKATRAO

# %%
inventory={"pen":50,"notebook":5,"eraser":0,"ruler":12}
inventory.items()
print(inventory)
if 'pencil' in inventory:
    print(inventory['pencil'])
else:
    print("product not found")
if inventory['eraser']==0:
    print("OUT OF STOCK")
elif inventory['eraser']<=10:
    print("LOW STOCK")
if inventory['notebook']==0:
    print("OUT OF STOCK")
elif inventory['notebook']:
    print("LOW STOCK")
inventory['eraser']=30
inventory.update({'sharperner':25})
print(inventory)
# Out:
# {'pen': 50, 'notebook': 5, 'eraser': 0, 'ruler': 12}
# product not found
# OUT OF STOCK
# LOW STOCK
# {'pen': 50, 'notebook': 5, 'eraser': 30, 'ruler': 12, 'sharperner': 25}
