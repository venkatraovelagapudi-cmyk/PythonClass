# %%
# tuple immutable
t=(1,2,3,4,1,2,"hi",[10,20,30],100)
print(t)
print(t[7])
t[7].append(100)
#t[3].append(100) #AttributeError: 'int' object has no attribute 'append'
#t[0]=10 #TypeError: 'tuple' object does not support item assignment
print(t)
#if tuple contains any elements as mutuable elements(i.e lsit,set and dictionary), you can perform on it
# operations,but doesnt change remaning elements postion and tuple object length also.
# Out:
# (1, 2, 3, 4, 1, 2, 'hi', [10, 20, 30], 100)
# [10, 20, 30]
# (1, 2, 3, 4, 1, 2, 'hi', [10, 20, 30, 100], 100)

# %%
# read tuple of integer
t=tuple(map(int,input().split()))

# %%
t=()
t2=tuple()
print(type(t))
print(type(t2))
# Out:
# <class 'tuple'>
# <class 'tuple'>

# %%
# single element representation
t1=(10)
t2=(15,)
print(type(t1))
print(type(t2))
# Out:
# <class 'int'>
# <class 'tuple'>

# %%
# in tuple we have count and repitation methods
