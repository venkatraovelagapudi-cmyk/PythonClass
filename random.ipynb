# %%
import random

# %%
print(random.random()) # it genrate random number between 0-1
print(random.randint(1,6)) # it genrates random number between range
print(random.choice(['a','b','c'])) # it return random item from seq
# Out:
# 0.6573900018235677
# 4
# a

# %%
import random
print("Welcome to the who will reach top in less chances")
steps=0
chances=0
while True:
    input("To throw a dice for that click on enter button")
    dice_val=random.randint(1,6
                           )
    chances+=1
    if steps+dice_val<=100:
        steps+=dice_val
    if steps==100:
        break
    if steps>90:
        print(f"hello buddy your at steps {steps} and total chances are {chances} and you need {100-steps} to reach top")
    else:
        print(f"hello buddy your at steps {steps} and total chances are {chances}")
# Out:
# Welcome to the who will reach top in less chances
# To throw a dice for that click on enter button
# hello buddy your at steps 5 and total chances are 1
# To throw a dice for that click on enter button
# hello buddy your at steps 10 and total chances are 2
# To throw a dice for that click on enter button
# hello buddy your at steps 14 and total chances are 3
# To throw a dice for that click on enter button
# hello buddy your at steps 19 and total chances are 4
# To throw a dice for that click on enter button
# hello buddy your at steps 24 and total chances are 5
# To throw a dice for that click on enter button
# hello buddy your at steps 26 and total chances are 6
# To throw a dice for that click on enter button
# hello buddy your at steps 31 and total chances are 7
# To throw a dice for that click on enter button
# hello buddy your at steps 36 and total chances are 8
# To throw a dice for that click on enter button
# hello buddy your at steps 39 and total chances are 9
# ...
